# %% [markdown]
# **NOTE:** You probably will see warnings. These are not errors! However, you should read them and try to understand why they're there. Can you fix them?

# %% [markdown]
# ![](http://rentinginla.com/wp-content/uploads/2015/12/Buying.jpg)
# # [Project 2: Predicting House Prices with Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)
#
# The goal of this project is for you to use EDA, visualization, data cleaning, preprocesing, and linear models to predict home prices given the features of the home, and interpret your linear models to find out what features add value to a home! This project is a bit more open-ended than project 1.
#
# Be sure to ...
#
# * Think about your choices when it comes to your choices about the data. Be ready to defend your decisions!
# * Use lots of plots to dig deeper into the data! Describe the plots and convey what you learned from them.
# * Don't forget to read the [description of the data](../data_description.txt) (also available at the kaggle website)! This has valuable information that will help you clean and impute data. `NaN` means something in many of the columns! Don't just drop or fill them!
# * Try fitting many models! Document your work and note what you've tried.
# * Apply what you've learned in class, books, videos, Kaggle forums, and blog posts. There have been a TON of blog posts about this;  you should seek them out and read them!
#
#
# From the Kaggle competition website:
#
#     Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
#
#     With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

import seaborn as sns

from IPython.display import display

# %matplotlib inline 
np.random.seed(42)

# %% [markdown]
# ## 1. Load the Data
#
# * The data comes in three separate CSVs located in `../data/`.
# * Load the CSV into a `DataFrame`.
# * Make sure to check the `.head` or `.sample`. How many rows? How many columns?
# * Familiarize yourself with the column names and what they represent.
# * Is there a column that can be set as the `index`? If so, set that column as the index when loading the data. (`df.set_index()`)

# %%
Housing = pd.read_csv("../data/train.csv", index_col = "Id")
Housing_df = pd.DataFrame(Housing)
Housing_df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          NaN       0      2    2008        WD         Normal     208500
# 2          NaN       0      5    2007        WD         Normal     181500
# 3          NaN       0      9    2008        WD         Normal     223500
# 4          NaN       0      2    2006        WD        Abnorml     140000
# 5          NaN       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
Housing_df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 37 columns]

# %%
Housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %% [markdown]
# Drop `Alley` because > 80% of the possible values are null. It is difficult to assume how to impute 80% of the values with only 20% of information

# %%
Housing_df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# **Bonus:** Write an assertion statement to programmatically verify the correct number of rows and columns were imported.

# %%
assert len(Housing_df.columns) == 80

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### A. Data Types
#
# Read the data description on Kaggle. Which variables are numerical and categorical? Are there any columns that can be deleted?
#
# Make sure the `dtype` of each column is correct.
#
# **NOTE:** There is one column in particular that should be categorical but will load in pandas as numeric.

# %%
Housing_df.loc[:, Housing_df.isnull().any()]
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# Id
# 1            65.0   NaN    BrkFace       196.0       Gd       TA           No
# 2            80.0   NaN       None         0.0       Gd       TA           Gd
# 3            68.0   NaN    BrkFace       162.0       Gd       TA           Mn
# 4            60.0   NaN       None         0.0       TA       Gd           No
# 5            84.0   NaN    BrkFace       350.0       Gd       TA           Av
# 6            85.0   NaN       None         0.0       Gd       TA           No
# 7            75.0   NaN      Stone       186.0       Ex       TA           Av
# 8             NaN   NaN      Stone       240.0       Gd       TA           Mn
# 9            51.0   NaN       None         0.0       TA       TA           No
# 10           50.0   NaN       None         0.0       TA       TA           No
# 11           70.0   NaN       None         0.0       TA       TA           No
# 12           85.0   NaN      Stone       286.0       Ex       TA           No
# 13            NaN   NaN       None         0.0       TA       TA           No
# 14           91.0   NaN      Stone       306.0       Gd       TA           Av
# 15            NaN   NaN    BrkFace       212.0       TA       TA           No
# 16           51.0   NaN       None         0.0       TA       TA           No
# 17            NaN   NaN    BrkFace       180.0       TA       TA           No
# 18           72.0   NaN       None         0.0      NaN      NaN          NaN
# 19           66.0   NaN       None         0.0       TA       TA           No
# 20           70.0   NaN       None         0.0       TA       TA           No
# 21          101.0   NaN    BrkFace       380.0       Ex       TA           Av
# 22           57.0  Grvl       None         0.0       TA       TA           No
# 23           75.0   NaN    BrkFace       281.0       Gd       TA           No
# 24           44.0   NaN       None         0.0       Gd       TA           No
# 25            NaN   NaN       None         0.0       TA       TA           Mn
# 26          110.0   NaN      Stone       640.0       Gd       TA           No
# 27           60.0   NaN       None         0.0       TA       TA           Mn
# 28           98.0   NaN      Stone       200.0       Ex       TA           No
# 29           47.0   NaN       None         0.0       TA       TA           Gd
# 30           60.0   NaN       None         0.0       TA       TA           No
# ...           ...   ...        ...         ...      ...      ...          ...
# 1431         60.0   NaN       None         0.0       Gd       Gd           Av
# 1432          NaN   NaN       None         0.0       Gd       TA           No
# 1433         60.0  Grvl       None         0.0       TA       TA           No
# 1434         93.0   NaN    BrkFace       318.0       Gd       TA           No
# 1435         80.0   NaN       None         0.0       TA       TA           No
# 1436         80.0   NaN    BrkFace       237.0       TA       TA           No
# 1437         60.0   NaN       None         0.0       TA       TA           No
# 1438         96.0   NaN      Stone       426.0       Ex       TA           Av
# 1439         90.0   NaN       None         0.0       TA       TA           No
# 1440         80.0   NaN    BrkFace        96.0       TA       TA           No
# 1441         79.0   NaN       None         0.0       Ex       TA           No
# 1442          NaN   NaN    BrkFace       147.0       Gd       TA           Av
# 1443         85.0   NaN      Stone       160.0       Ex       TA           Av
# 1444          NaN   NaN       None         0.0       TA       TA           No
# 1445         63.0   NaN    BrkFace       106.0       Gd       TA           Av
# 1446         70.0   NaN       None         0.0       TA       TA           Gd
# 1447          NaN   NaN    BrkFace       189.0       TA       TA           No
# 1448         80.0   NaN    BrkFace       438.0       Gd       TA           No
# 1449         70.0   NaN       None         0.0       Fa       TA           No
# 1450         21.0   NaN       None         0.0       Gd       TA           Av
# 1451         60.0   NaN       None         0.0       Gd       TA           No
# 1452         78.0   NaN      Stone       194.0       Gd       TA           No
# 1453         35.0   NaN    BrkFace        80.0       Gd       TA           Gd
# 1454         90.0   NaN       None         0.0       Gd       TA           No
# 1455         62.0  Pave       None         0.0       Gd       TA           No
# 1456         62.0   NaN       None         0.0       Gd       TA           No
# 1457         85.0   NaN      Stone       119.0       Gd       TA           No
# 1458         66.0   NaN       None         0.0       TA       Gd           No
# 1459         68.0   NaN       None         0.0       TA       TA           Mn
# 1460         75.0   NaN       None         0.0       TA       TA           No
#
#      BsmtFinType1 BsmtFinType2 Electrical FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1             GLQ          Unf      SBrkr         NaN     Attchd       2003.0
# 2             ALQ          Unf      SBrkr          TA     Attchd       1976.0
# 3             GLQ          Unf      SBrkr          TA     Attchd       2001.0
# 4             ALQ          Unf      SBrkr          Gd     Detchd       1998.0
# 5             GLQ          Unf      SBrkr          TA     Attchd       2000.0
# 6             GLQ          Unf      SBrkr         NaN     Attchd       1993.0
# 7             GLQ          Unf      SBrkr          Gd     Attchd       2004.0
# 8             ALQ          BLQ      SBrkr          TA     Attchd       1973.0
# 9             Unf          Unf      FuseF          TA     Detchd       1931.0
# 10            GLQ          Unf      SBrkr          TA     Attchd       1939.0
# 11            Rec          Unf      SBrkr         NaN     Detchd       1965.0
# 12            GLQ          Unf      SBrkr          Gd    BuiltIn       2005.0
# 13            ALQ          Unf      SBrkr         NaN     Detchd       1962.0
# 14            Unf          Unf      SBrkr          Gd     Attchd       2006.0
# 15            BLQ          Unf      SBrkr          Fa     Attchd       1960.0
# 16            Unf          Unf      FuseA         NaN     Detchd       1991.0
# 17            ALQ          Unf      SBrkr          TA     Attchd       1970.0
# 18            NaN          NaN      SBrkr         NaN    CarPort       1967.0
# 19            GLQ          Unf      SBrkr         NaN     Detchd       2004.0
# 20            LwQ          Unf      SBrkr         NaN     Attchd       1958.0
# 21            Unf          Unf      SBrkr          Gd    BuiltIn       2005.0
# 22            Unf          Unf      FuseF          Gd     Attchd       1930.0
# 23            Unf          Unf      SBrkr          Gd     Attchd       2002.0
# 24            GLQ          Unf      SBrkr          TA     Attchd       1976.0
# 25            Rec          ALQ      SBrkr          TA     Attchd       1968.0
# 26            Unf          Unf      SBrkr          Gd     Attchd       2007.0
# 27            BLQ          Rec      SBrkr         NaN     Detchd       2005.0
# 28            GLQ          Unf      SBrkr          Gd     Attchd       2008.0
# 29            BLQ          Unf      SBrkr          Gd     Attchd       1957.0
# 30            Unf          Unf      SBrkr         NaN     Detchd       1920.0
# ...           ...          ...        ...         ...        ...          ...
# 1431          Unf          Unf      SBrkr          Gd    BuiltIn       2005.0
# 1432          LwQ          Unf      SBrkr         NaN     Attchd       1976.0
# 1433          Unf          Unf      SBrkr         NaN     Detchd       1928.0
# 1434          Unf          Unf      SBrkr          TA     Attchd       2000.0
# 1435          ALQ          Unf      SBrkr          Gd     Attchd       1977.0
# 1436          Unf          Unf      SBrkr          Gd     Attchd       1962.0
# 1437          ALQ          Unf      SBrkr         NaN     Detchd       1974.0
# 1438          GLQ          Unf      SBrkr          Gd     Attchd       2008.0
# 1439          GLQ          Unf      FuseA         NaN     Attchd       1957.0
# 1440          GLQ          Rec      SBrkr          TA     Attchd       1979.0
# 1441          Unf          Unf      SBrkr          Gd     Detchd       1993.0
# 1442          GLQ          Unf      SBrkr          TA     Attchd       2004.0
# 1443          GLQ          Unf      SBrkr          Ex     Attchd       2008.0
# 1444          Unf          Unf      FuseF          Gd     Detchd       1916.0
# 1445          Unf          Unf      SBrkr         NaN     Attchd       2004.0
# 1446          LwQ          Rec      SBrkr         NaN     Detchd       1990.0
# 1447          Rec          Unf      SBrkr         NaN     Attchd       1962.0
# 1448          GLQ          Unf      SBrkr          TA     Attchd       1995.0
# 1449          Unf          Unf      SBrkr         NaN     Detchd       1950.0
# 1450          GLQ          Unf      SBrkr         NaN        NaN          NaN
# 1451          Unf          Unf      SBrkr         NaN        NaN          NaN
# 1452          Unf          Unf      SBrkr          Gd     Attchd       2008.0
# 1453          GLQ          Unf      SBrkr         NaN    Basment       2005.0
# 1454          Unf          Unf      SBrkr         NaN        NaN          NaN
# 1455          GLQ          Unf      SBrkr         NaN     Attchd       2004.0
# 1456          Unf          Unf      SBrkr          TA     Attchd       1999.0
# 1457          ALQ          Rec      SBrkr          TA     Attchd       1978.0
# 1458          GLQ          Unf      SBrkr          Gd     Attchd       1941.0
# 1459          GLQ          Rec      FuseA         NaN     Attchd       1950.0
# 1460          BLQ          LwQ      SBrkr         NaN     Attchd       1965.0
#
#      GarageFinish GarageQual GarageCond PoolQC  Fence MiscFeature
# Id
# 1             RFn         TA         TA    NaN    NaN         NaN
# 2             RFn         TA         TA    NaN    NaN         NaN
# 3             RFn         TA         TA    NaN    NaN         NaN
# 4             Unf         TA         TA    NaN    NaN         NaN
# 5             RFn         TA         TA    NaN    NaN         NaN
# 6             Unf         TA         TA    NaN  MnPrv        Shed
# 7             RFn         TA         TA    NaN    NaN         NaN
# 8             RFn         TA         TA    NaN    NaN        Shed
# 9             Unf         Fa         TA    NaN    NaN         NaN
# 10            RFn         Gd         TA    NaN    NaN         NaN
# 11            Unf         TA         TA    NaN    NaN         NaN
# 12            Fin         TA         TA    NaN    NaN         NaN
# 13            Unf         TA         TA    NaN    NaN         NaN
# 14            RFn         TA         TA    NaN    NaN         NaN
# 15            RFn         TA         TA    NaN   GdWo         NaN
# 16            Unf         TA         TA    NaN  GdPrv         NaN
# 17            Fin         TA         TA    NaN    NaN        Shed
# 18            Unf         TA         TA    NaN    NaN        Shed
# 19            Unf         TA         TA    NaN    NaN         NaN
# 20            Unf         TA         TA    NaN  MnPrv         NaN
# 21            RFn         TA         TA    NaN    NaN         NaN
# 22            Unf         TA         TA    NaN  GdPrv         NaN
# 23            RFn         TA         TA    NaN    NaN         NaN
# 24            Unf         TA         TA    NaN    NaN         NaN
# 25            Unf         TA         TA    NaN  MnPrv         NaN
# 26            RFn         TA         TA    NaN    NaN         NaN
# 27            Unf         TA         TA    NaN    NaN         NaN
# 28            RFn         TA         TA    NaN    NaN         NaN
# 29            RFn         TA         TA    NaN    NaN         NaN
# 30            Unf         Fa         TA    NaN    NaN         NaN
# ...           ...        ...        ...    ...    ...         ...
# 1431          Fin         TA         TA    NaN    NaN         NaN
# 1432          RFn         TA         TA    NaN    NaN         NaN
# 1433          Unf         Fa         Fa    NaN    NaN         NaN
# 1434          Fin         TA         TA    NaN    NaN         NaN
# 1435          RFn         TA         TA    NaN    NaN         NaN
# 1436          RFn         TA         TA    NaN  GdPrv         NaN
# 1437          Unf         TA         TA    NaN   GdWo         NaN
# 1438          Fin         TA         TA    NaN    NaN         NaN
# 1439          Unf         TA         TA    NaN  MnPrv         NaN
# 1440          RFn         TA         TA    NaN    NaN         NaN
# 1441          Fin         TA         TA    NaN    NaN         NaN
# 1442          RFn         TA         TA    NaN    NaN         NaN
# 1443          Fin         TA         TA    NaN    NaN         NaN
# 1444          Unf         Fa         Po    NaN    NaN         NaN
# 1445          RFn         TA         TA    NaN    NaN         NaN
# 1446          Unf         TA         TA    NaN    NaN         NaN
# 1447          Unf         TA         TA    NaN    NaN         NaN
# 1448          RFn         TA         TA    NaN    NaN         NaN
# 1449          Unf         Fa         TA    NaN   GdWo         NaN
# 1450          NaN        NaN        NaN    NaN    NaN         NaN
# 1451          NaN        NaN        NaN    NaN    NaN         NaN
# 1452          Fin         TA         TA    NaN    NaN         NaN
# 1453          Fin         TA         TA    NaN    NaN         NaN
# 1454          NaN        NaN        NaN    NaN    NaN         NaN
# 1455          RFn         TA         TA    NaN    NaN         NaN
# 1456          RFn         TA         TA    NaN    NaN         NaN
# 1457          Unf         TA         TA    NaN  MnPrv         NaN
# 1458          RFn         TA         TA    NaN  GdPrv        Shed
# 1459          Unf         TA         TA    NaN    NaN         NaN
# 1460          Fin         TA         TA    NaN    NaN         NaN
#
# [1460 rows x 19 columns]

# %%
Housing.isnull().sum().nlargest(12).plot(kind="barh")

# %%
Housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %% [markdown]
# ### B. Plot histograms of the numeric columns.

# %%
Housing.isnull().sum().nlargest(12).plot(kind="barh")

# %%
def delete_cols(df, col):
    return df.drop(col, axis =1)

# %% [markdown]
# Delete Columns with redundant data or that are missing 80% of data

# %%
nullCols = ['Alley', 'FireplaceQu' , 'PoolQC', 'MiscFeature', 'Fence','ScreenPorch','MiscVal',"3SsnPorch", 'GarageQual' , 'BsmtCond','Condition2','BsmtUnfSF','BsmtFinSF1', "BsmtFinSF2", 'BsmtFinType2','OverallCond', "Exterior2nd" ,'GarageArea']

# %%
Housing = delete_cols(Housing_df, nullCols)

# %%
num_cols = ['LotFrontage','LotArea','SalePrice','MSSubClass', 'OverallQual', 'YearBuilt', 'YearRemodAdd','MasVnrArea'\
            ,'TotalBsmtSF','1stFlrSF','2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'HalfBath',\
            'BedroomAbvGr','KitchenAbvGr' , 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'WoodDeckSF'\
           ,'OpenPorchSF', 'EnclosedPorch', 'PoolArea', 'MoSold', 'YrSold']
cat_cols = [i for i in Housing.columns if i not in num_cols]

numeric_df = Housing[num_cols]
cat_df = Housing[cat_cols]

target = Housing['SalePrice']

delete_cols(Housing, "SalePrice")


fig = plt.figure(figsize=(15,70))
for i, col in enumerate(num_cols):
    fig.add_subplot(13,3,1+i)
    Housing[col].hist()
    plt.title(col)

# %% [markdown]
# #### What are your observations? Add them to this markdown cell.
#
# ---

# %% [markdown]
# ### C. Plot the Numeric Columns Against `SalePrice` using scatter plots.

# %%
fig = plt.figure(figsize=(15,70))
for i, col in enumerate(num_cols):
    fig.add_subplot(13,3,1+i)
    plt.scatter(Housing[col], Housing["SalePrice"])
    plt.title(col)

# %% [markdown]
# #### What are your observations? Add them to this markdown cell.
#
# ---Well the its just really obvious which ones will be the most useful and correlated data, the ones that impact sale price have a sort of linear shape or almost like a cone, the ones that have little effect almost look like a bar graph

# %% [markdown]
# ### D. Use bar plots to plot categorical features against `SalePrice`.
#
# **HINT:** Look up how to create bar plots in `matplotlib`. You will have to transform the data before you can create a bar plot! Also, look up [how to plot error bars](https://pandas.pydata.org/pandas-docs/stable/visualization.html#plotting-with-error-bars) so you can also observe the variability in your data!

# %%
cat_df.head()
# Out:
#    MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2        RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 3        RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4        RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 5        RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#    Neighborhood Condition1 BldgType      ...      BsmtHalfBath FullBath  \
# Id                                       ...
# 1       CollgCr       Norm     1Fam      ...                 0        2
# 2       Veenker      Feedr     1Fam      ...                 1        2
# 3       CollgCr       Norm     1Fam      ...                 0        2
# 4       Crawfor       Norm     1Fam      ...                 0        1
# 5       NoRidge       Norm     1Fam      ...                 0        2
#
#    KitchenQual Functional GarageType GarageFinish GarageCond PavedDrive  \
# Id
# 1           Gd        Typ     Attchd          RFn         TA          Y
# 2           TA        Typ     Attchd          RFn         TA          Y
# 3           Gd        Typ     Attchd          RFn         TA          Y
# 4           Gd        Typ     Detchd          Unf         TA          Y
# 5           Gd        Typ     Attchd          RFn         TA          Y
#
#    SaleType SaleCondition
# Id
# 1        WD        Normal
# 2        WD        Normal
# 3        WD        Normal
# 4        WD       Abnorml
# 5        WD        Normal
#
# [5 rows x 35 columns]

# %%
fig = plt.figure(figsize=(15,120))

i=1
for column in cat_df.columns:
    fig.add_subplot(21,3,i)

    errors = Housing.groupby(column)['SalePrice'].std()
    
    Housing.groupby(column)['SalePrice'].mean().plot.bar(yerr = errors)
    means = cat_df
    plt.xlabel(column)
    plt.subplots_adjust(hspace = .3)
    
    i+=1

# %% [markdown]
# ## 3. Preprocessing

# %% [markdown]
# ### A. Identify and Remove Outliers for `SalePrice`
#
# Make sure to...
# * Plot a histogram of the housing price.
# * Supply a definition of what an outlier is by your criteria. Does Tukey's method make sense with 1.5 times the interquartile range, or should that range be increased or decreased?
# * Use masking to remove the outliers as you've defined them.

# %%
plt.hist(Housing['SalePrice'])

rowmask = np.abs(stats.zscore(Housing["SalePrice"])) < 3.72 #remove 1% outliers

Housing = Housing[rowmask].sort_values(by="SalePrice")

# %% [markdown]
# ### B. Fill missing data!
#
# * How many null values are in each column? Make a bar plot showing this only for columns with missing data.
# * For each column with nulls, do nulls represent anything? Read the data description.
#   * Some columns that are appearing as _null_ might legitimately be known (ie: "na").  Double check the [data description](../data_description.txt) for proper value representation.  A feature might actually be better represented by "not available" or "na" rather than `NULL` or `NaN`.  There's a difference between `NULL` (unknown), and "NA" (not available).  It might mean the difference between "there isn't a garage" and "there is no garage data".
# * Fill null values for each column by imputation. Here are some common methods for imputation:
#   1. Using domain knowledge to select an appropriate value.
#   1. Value from a randomly selected row.
#   2. Mean, median, or mode value of the series.
#   3. Value estimated by a predictive model.
# * Make sure to justify your method for filling null values.

# %%
Housing.LotFrontage.fillna(Housing.LotFrontage.mean(), inplace=True)
def fill_mean(df,column):
    return df[column].fillna(df[column].mean(), inplace=True)




'''Houses of similar value are bound to have similar features. Replace null values with the value of the
house before it'''
Housing = Housing.sort_values('SalePrice', ascending = True)

def fill_lazy(df,column):
    return df[column].fillna(method = 'bfill', inplace=True)



fill_mean(Housing, 'MasVnrArea')
fill_mean(Housing, 'GarageYrBlt')
fill_lazy(Housing,"GarageType")
fill_lazy(Housing,"GarageFinish")
fill_lazy(Housing,"GarageCond")
fill_lazy(Housing,"BsmtExposure")
fill_lazy(Housing,"BsmtQual")
fill_lazy(Housing,"BsmtFinType1")
fill_lazy(Housing,"MasVnrType")
fill_lazy(Housing,"Electrical")


Housing
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 496           30  C (all)    60.000000     7879   Pave      Reg         Lvl
# 917           20  C (all)    50.000000     9000   Pave      Reg         Lvl
# 969           50       RM    50.000000     5925   Pave      Reg         Lvl
# 534           20       RL    50.000000     5000   Pave      Reg         Low
# 31            70  C (all)    50.000000     8500   Pave      Reg         Lvl
# 711           30       RL    56.000000     4130   Pave      IR1         Lvl
# 1338          30       RM   153.000000     4118   Pave      IR1         Bnk
# 1326          30       RM    40.000000     3636   Pave      Reg         Lvl
# 706          190       RM    70.000000     5600   Pave      Reg         Lvl
# 813           20  C (all)    66.000000     8712   Grvl      Reg         Bnk
# 1381          30       RL    45.000000     8212   Pave      Reg         Lvl
# 1101          30       RL    60.000000     8400   Pave      Reg         Bnk
# 637           30       RM    51.000000     6120   Pave      Reg         Lvl
# 411           20       RL    68.000000     9571   Pave      Reg         Lvl
# 376           30       RL    69.804366    10020   Pave      IR1         Low
# 463           20       RL    60.000000     8281   Pave      IR1         Lvl
# 1433          30       RL    60.000000    10800   Pave      Reg         Lvl
# 875           50       RM    52.000000     5720   Pave      Reg         Lvl
# 399           30       RM    60.000000     8967   Pave      Reg         Lvl
# 621           30       RL    45.000000     8248   Pave      Reg         Lvl
# 1280          50  C (all)    60.000000     7500   Pave      Reg         Lvl
# 30            30       RM    60.000000     6324   Pave      IR1         Lvl
# 1322          20       RL    69.804366     6627   Pave      IR1         Lvl
# 265           30       RM    30.000000     5232   Pave      IR3         Bnk
# 916          160       RM    21.000000     2001   Pave      Reg         Lvl
# 615          180       RM    21.000000     1491   Pave      Reg         Lvl
# 384           45       RH    60.000000     9000   Pave      Reg         Lvl
# 251           30       RL    55.000000     5350   Pave      IR1         Lvl
# 330           70       RM    60.000000     6402   Pave      Reg         Lvl
# 1327          30       RH    70.000000     4270   Pave      Reg         Bnk
# ...          ...      ...          ...      ...    ...      ...         ...
# 478           60       RL   105.000000    13693   Pave      Reg         Lvl
# 1269          50       RL    69.804366    14100   Pave      IR1         Lvl
# 113           60       RL    77.000000     9965   Pave      Reg         Lvl
# 54            20       RL    68.000000    50271   Pave      IR1         Low
# 826           20       RL   114.000000    14803   Pave      Reg         Lvl
# 225           20       RL   103.000000    13472   Pave      Reg         Lvl
# 689           20       RL    60.000000     8089   Pave      Reg         HLS
# 1182         120       RM    64.000000     5587   Pave      IR1         HLS
# 379           20       RL    88.000000    11394   Pave      Reg         Lvl
# 1438          20       RL    96.000000    12444   Pave      Reg         Lvl
# 775           20       RL   110.000000    14226   Pave      Reg         Lvl
# 988           20       RL    83.000000    10159   Pave      IR1         Lvl
# 662           60       RL    52.000000    46589   Pave      IR2         Lvl
# 516           20       RL    94.000000    12220   Pave      Reg         Lvl
# 232           60       RL   174.000000    15138   Pave      IR1         Lvl
# 1354          50       RL    56.000000    14720   Pave      IR1         Lvl
# 162           60       RL   110.000000    13688   Pave      IR1         Lvl
# 279           20       RL   107.000000    14450   Pave      Reg         Lvl
# 665           20       RL    49.000000    20896   Pave      IR2         Lvl
# 1143          60       RL    77.000000     9965   Pave      Reg         Lvl
# 390           60       RL    96.000000    12474   Pave      Reg         Lvl
# 497           20       RL    69.804366    12692   Pave      IR1         Lvl
# 350           60       RL    56.000000    20431   Pave      IR2         Lvl
# 59            60       RL    66.000000    13682   Pave      IR2         HLS
# 474           20       RL   110.000000    14977   Pave      IR1         Lvl
# 528           60       RL    67.000000    14948   Pave      IR1         Lvl
# 592           60       RL    97.000000    13478   Pave      IR1         Lvl
# 1244          20       RL   107.000000    13891   Pave      Reg         Lvl
# 1374          20       RL    69.804366    11400   Pave      Reg         Lvl
# 186           75       RM    90.000000    22950   Pave      IR2         Lvl
#
#      Utilities LotConfig LandSlope    ...    PavedDrive WoodDeckSF  \
# Id                                    ...
# 496     AllPub    Inside       Gtl    ...             N          0
# 917     AllPub    Inside       Gtl    ...             Y          0
# 969     AllPub    Inside       Gtl    ...             Y          0
# 534     AllPub    Inside       Mod    ...             N          0
# 31      AllPub    Inside       Gtl    ...             N          0
# 711     AllPub    Inside       Gtl    ...             N          0
# 1338    AllPub    Corner       Mod    ...             N          0
# 1326    AllPub    Inside       Gtl    ...             N          0
# 706     AllPub    Inside       Gtl    ...             N          0
# 813     AllPub    Inside       Mod    ...             N          0
# 1381    AllPub    Inside       Gtl    ...             Y          0
# 1101    AllPub    Inside       Gtl    ...             N          0
# 637     AllPub    Inside       Gtl    ...             N          0
# 411     AllPub    Inside       Gtl    ...             Y          0
# 376     AllPub    Inside       Sev    ...             Y          0
# 463     AllPub    Inside       Gtl    ...             Y          0
# 1433    AllPub    Inside       Gtl    ...             Y          0
# 875     AllPub    Inside       Gtl    ...             Y         26
# 399     AllPub    Corner       Gtl    ...             N          0
# 621     AllPub    Inside       Gtl    ...             N          0
# 1280    AllPub    Inside       Gtl    ...             Y         30
# 30      AllPub    Inside       Gtl    ...             Y         49
# 1322    AllPub    Corner       Gtl    ...             Y          0
# 265     AllPub    Inside       Gtl    ...             N          0
# 916     AllPub    Inside       Gtl    ...             Y          0
# 615     AllPub    Inside       Gtl    ...             Y         96
# 384     AllPub    Corner       Gtl    ...             N          0
# 251     AllPub    Inside       Gtl    ...             Y        263
# 330     AllPub    Corner       Gtl    ...             N          0
# 1327    AllPub    Inside       Mod    ...             Y          0
# ...        ...       ...       ...    ...           ...        ...
# 478     AllPub    Inside       Gtl    ...             Y        414
# 1269    AllPub    Inside       Mod    ...             Y        314
# 113     AllPub    Inside       Gtl    ...             Y        120
# 54      AllPub    Inside       Gtl    ...             Y        857
# 826     AllPub    Inside       Gtl    ...             Y        188
# 225     AllPub    Inside       Gtl    ...             Y        248
# 689     AllPub    Inside       Gtl    ...             Y        140
# 1182    AllPub    Inside       Mod    ...             Y        162
# 379     AllPub    Corner       Gtl    ...             Y        113
# 1438    AllPub       FR2       Gtl    ...             Y          0
# 775     AllPub    Corner       Gtl    ...             Y        315
# 988     AllPub    Inside       Gtl    ...             Y        168
# 662     AllPub   CulDSac       Gtl    ...             Y        517
# 516     AllPub    Inside       Gtl    ...             Y        156
# 232     AllPub    Inside       Gtl    ...             Y          0
# 1354    AllPub   CulDSac       Gtl    ...             Y        283
# 162     AllPub    Inside       Gtl    ...             Y        400
# 279     AllPub    Inside       Gtl    ...             Y        124
# 665     AllPub   CulDSac       Gtl    ...             Y        192
# 1143    AllPub    Inside       Gtl    ...             Y        125
# 390     AllPub    Inside       Gtl    ...             Y        196
# 497     AllPub    Inside       Gtl    ...             Y        264
# 350     AllPub    Inside       Gtl    ...             Y          0
# 59      AllPub   CulDSac       Gtl    ...             Y        192
# 474     AllPub    Inside       Gtl    ...             Y        250
# 528     AllPub    Inside       Gtl    ...             Y        126
# 592     AllPub    Corner       Gtl    ...             Y        382
# 1244    AllPub    Inside       Gtl    ...             Y        216
# 1374    AllPub    Inside       Gtl    ...             Y        314
# 186     AllPub    Inside       Gtl    ...             Y          0
#
#      OpenPorchSF EnclosedPorch  PoolArea  MoSold  YrSold SaleType  \
# Id
# 496          523           115         0      11    2009       WD
# 917            0             0         0      10    2006       WD
# 969            0             0         0       5    2009       WD
# 534            0             0         0       1    2007       WD
# 31            54           172         0       7    2008       WD
# 711            0             0         0       7    2008       WD
# 1338          20             0         0       3    2006       WD
# 1326           0           100         0       1    2008       WD
# 706            0             0         0       7    2010       WD
# 813            0             0         0       6    2010       WD
# 1381           0            96         0       6    2010       WD
# 1101           0             0         0       1    2009       WD
# 637            0             0         0       1    2009    ConLw
# 411            0             0         0       6    2009      COD
# 376            0             0         0       3    2009       WD
# 463            0           236         0      12    2009       WD
# 1433           0             0         0       8    2007       WD
# 875            0             0         0       8    2009       WD
# 399            0             0         0      11    2007       WD
# 621            0           100         0       9    2008       WD
# 1280           0           164         0       4    2010      COD
# 30             0            87         0       5    2008       WD
# 1322           0             0         0       7    2008       WD
# 265            0             0         0       6    2008       WD
# 916            0             0         0       1    2007       WD
# 615           24             0         0       5    2010       WD
# 384            0            91         0      10    2009       WD
# 251            0             0         0       5    2010       WD
# 330            0           137         0       7    2009       WD
# 1327           0           286         0       5    2007       WD
# ...          ...           ...       ...     ...     ...      ...
# 478           84             0         0       3    2007       WD
# 1269          12             0         0       5    2008       WD
# 113          184             0         0      10    2007      New
# 54            72             0         0      11    2006       WD
# 826           45             0         0       6    2008      New
# 225          105             0         0       6    2009       WD
# 689            0             0         0      10    2007      New
# 1182          53             0         0      11    2008      New
# 379            0             0         0       6    2010      New
# 1438          66             0         0      11    2008      New
# 775           45             0         0       7    2007      New
# 988           95             0         0       4    2010      New
# 662           76             0         0       7    2009       WD
# 516           54             0         0       9    2009      New
# 232          146           202         0       7    2009       WD
# 1354          86             0         0       3    2010       WD
# 162            0             0         0       3    2008       WD
# 279           98             0         0       5    2007      New
# 665          267             0         0       1    2006      New
# 1143         144             0         0       4    2007      New
# 390          134             0         0       8    2008      New
# 497           75           291         0       5    2007       WD
# 350            0             0         0       4    2006      New
# 59             0            37         0      10    2006      New
# 474           63             0         0       7    2007      New
# 528           66             0         0      11    2008      New
# 592          274             0         0       6    2009    ConLI
# 1244         229             0         0       9    2006      New
# 1374         140             0         0       3    2007       WD
# 186          260             0         0       6    2006       WD
#
#      SaleCondition SalePrice
# Id
# 496        Abnorml     34900
# 917        Abnorml     35311
# 969        Abnorml     37900
# 534         Normal     39300
# 31          Normal     40000
# 711         Normal     52000
# 1338        Normal     52500
# 1326        Normal     55000
# 706         Normal     55000
# 813         Alloca     55993
# 1381        Normal     58500
# 1101        Normal     60000
# 637         Normal     60000
# 411        Abnorml     60000
# 376         Normal     61000
# 463         Normal     62383
# 1433        Normal     64500
# 875        Abnorml     66500
# 399        Abnorml     67000
# 621         Normal     67000
# 1280       Abnorml     68400
# 30          Normal     68500
# 1322        Normal     72500
# 265         Normal     73000
# 916         Normal     75000
# 615         Normal     75500
# 384         Normal     76000
# 251         Normal     76500
# 330         Normal     78000
# 1327        Normal     79000
# ...            ...       ...
# 478         Normal    380000
# 1269        Normal    381000
# 113        Partial    383970
# 54          Normal    385000
# 826        Partial    385000
# 225         Normal    386250
# 689        Partial    392000
# 1182       Partial    392500
# 379        Partial    394432
# 1438       Partial    394617
# 775        Partial    395000
# 988        Partial    395192
# 662         Normal    402000
# 516        Partial    402861
# 232         Normal    403000
# 1354        Normal    410000
# 162         Normal    412500
# 279        Partial    415298
# 665        Partial    423000
# 1143       Partial    424870
# 390        Partial    426000
# 497         Normal    430000
# 350        Partial    437154
# 59         Partial    438780
# 474        Partial    440000
# 528        Partial    446261
# 592         Normal    451950
# 1244       Partial    465000
# 1374        Normal    466500
# 186         Normal    475000
#
# [1450 rows x 62 columns]

# %% [markdown]
# Verify that you have *truly* eliminated all the null values!

# %% [markdown]
# ### D. Use bar plots to plot categorical features against `SalePrice`.
#
# **HINT:** Look up how to create bar plots in `matplotlib`. You will have to transform the data before you can create a bar plot! Also, look up [how to plot error bars](https://pandas.pydata.org/pandas-docs/stable/visualization.html#plotting-with-error-bars) so you can also observe the variability in your data!

# %%
Housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 496 to 186
# Data columns (total 62 columns):
# MSSubClass       1450 non-null int64
# MSZoning         1450 non-null object
# LotFrontage      1450 non-null float64
# LotArea          1450 non-null int64
# Street           1450 non-null object
# LotShape         1450 non-null object
# LandContour      1450 non-null object
# Utilities        1450 non-null object
# LotConfig        1450 non-null object
# LandSlope        1450 non-null object
# Neighborhood     1450 non-null object
# Condition1       1450 non-null object
# BldgType         1450 non-null object
# HouseStyle       1450 non-null object
# OverallQual      1450 non-null int64
# YearBuilt        1450 non-null int64
# YearRemodAdd     1450 non-null int64
# RoofStyle        1450 non-null object
# RoofMatl         1450 non-null object
# Exterior1st      1450 non-null object
# MasVnrType       1450 non-null object
# MasVnrArea       1450 non-null float64
# ExterQual        1450 non-null object
# ExterCond        1450 non-null object
# Foundation       1450 non-null object
# BsmtQual         1450 non-null object
# BsmtExposure     1450 non-null object
# BsmtFinType1     1450 non-null object
# TotalBsmtSF      1450 non-null int64
# Heating          1450 non-null object
# HeatingQC        1450 non-null object
# CentralAir       1450 non-null object
# Electrical       1450 non-null object
# 1stFlrSF         1450 non-null int64
# 2ndFlrSF         1450 non-null int64
# LowQualFinSF     1450 non-null int64
# GrLivArea        1450 non-null int64
# BsmtFullBath     1450 non-null int64
# BsmtHalfBath     1450 non-null int64
# FullBath         1450 non-null int64
# HalfBath         1450 non-null int64
# BedroomAbvGr     1450 non-null int64
# KitchenAbvGr     1450 non-null int64
# KitchenQual      1450 non-null object
# TotRmsAbvGrd     1450 non-null int64
# Functional       1450 non-null object
# Fireplaces       1450 non-null int64
# GarageType       1450 non-null object
# GarageYrBlt      1450 non-null float64
# GarageFinish     1450 non-null object
# GarageCars       1450 non-null int64
# GarageCond       1450 non-null object
# PavedDrive       1450 non-null object
# WoodDeckSF       1450 non-null int64
# OpenPorchSF      1450 non-null int64
# EnclosedPorch    1450 non-null int64
# PoolArea         1450 non-null int64
# MoSold           1450 non-null int64
# YrSold           1450 non-null int64
# SaleType         1450 non-null object
# SaleCondition    1450 non-null object
# SalePrice        1450 non-null int64
# dtypes: float64(3), int64(26), object(33)
# memory usage: 713.7+ KB

# %%
Housing.groupby("GarageYrBlt")["SalePrice"].mean().plot(kind = "bar")

# %% [markdown]
# ### C. Create dummy variables for categorical columns
#
# Use `pd.get_dummies()` to turn your categorical features into numeric features. Make sure there are **no null values** in your dataset before you do this!

# %%
target = Housing.SalePrice.copy()
Housing = Housing.drop('SalePrice', axis = 1)
cat_features_dummies = pd.get_dummies(Housing, columns=cat_cols)
cat_features_dummies.head()
# Out:
#      MSSubClass  LotFrontage  LotArea  OverallQual  YearBuilt  YearRemodAdd  \
# Id
# 496          30         60.0     7879            4       1920          1950
# 917          20         50.0     9000            2       1949          1950
# 969          50         50.0     5925            3       1910          1950
# 534          20         50.0     5000            1       1946          1950
# 31           70         50.0     8500            4       1920          1950
#
#      MasVnrArea  TotalBsmtSF  1stFlrSF  2ndFlrSF          ...            \
# Id                                                        ...
# 496         0.0          720       720         0          ...
# 917         0.0          480       480         0          ...
# 969         0.0          600       600       368          ...
# 534         0.0            0       334         0          ...
# 31          0.0          649       649       668          ...
#
#      SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# Id
# 496               0             0             0            1
# 917               0             0             0            1
# 969               0             0             0            1
# 534               0             0             0            1
# 31                0             0             0            1
#
#      SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# Id
# 496                      1                      0                     0
# 917                      1                      0                     0
# 969                      1                      0                     0
# 534                      0                      0                     0
# 31                       0                      0                     0
#
#      SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# Id
# 496                     0                     0                      0
# 917                     0                     0                      0
# 969                     0                     0                      0
# 534                     0                     1                      0
# 31                      0                     1                      0
#
# [5 rows x 228 columns]

# %% [markdown]
# ### D. Split your data into a train and test set.
#
# * Use `train_test_split` to hold out a test set.
# * Why do we hold out a test set?

# %%
from sklearn.model_selection import train_test_split

# %%
X = cat_features_dummies
y = target

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 25)

# %% [markdown]
# We hold out a test set because we need to understand how our model performs on data it hasn't seen. We may create a model that fits our training data very well but does not score well on the test set, suggesting that it won't predict well given new data. With a test set, we can understand how our model performs on unseen data.

# %% [markdown]
# ### E. Scale the data
#
# Make sure to...
# * instantiate a `StandardScaler` object
# * `fit` the scaler on your training data
# * `transform` both your training and test data.

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

#Xs= ss.fit_transform(X)
Xs_train = ss.fit_transform(X_train)
Xs_test= ss.fit_transform(X_test)

# %% [markdown]
# ## 4. Modeling
#
# Now that you've completed your EDA, you can now use your training data to build a model to predict home price from your features! As far as regression methods, you've learned a few, including ordinary least squares (a.k.a. `LinearRegression`), `Lasso`, `Ridge`, and `ElasticNet`.

# %% [markdown]
# ### A. Benchmarking
#
# As we get started with modeling we should have some basis for comparison to get a sense of what a "good" model is for this task.
#
# For this task, as we will be focusing on linear models, we will use the most naive of the linear models, the Linear Regression as our benchmark.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Results Dictionary

# %% [markdown]
# Make a results `list` to hold your results. After each model fit and score, you will add a dictionary of your results to this list using `.append()`. This will give you a list of dictionaries ... perfect for a DataFrame!
#
# This is the pattern you will be using:

# %%
example_results = list()
result_1 = {'name':'test1','dataset' : 'train','preprocessing': 'raw','score': '1 bajillion'}
example_results.append(result_1)
result_2 = {'name':'test1','dataset' : 'train','preprocessing': 'scaled','score': '20 bajillion'}
example_results.append(result_2)

# %% [markdown]
# Then we pass the results list to pass to a DataFrame.

# %%
pd.DataFrame(example_results)
# Out:
#   dataset   name preprocessing         score
# 0   train  test1           raw   1 bajillion
# 1   train  test1        scaled  20 bajillion

# %% [markdown]
# This gives us a convenient tool for manipulating our results and tracking our work ... our old friend, Pandas!

# %% [markdown]
# #### Make a new results list.

# %%
results = list()

# %% [markdown]
# #### Raw Benchmark

# %% [markdown]
# Instantiate a new `LinearRegression` model and save it as `benchmark_raw`.

# %%
benchmark_raw = LinearRegression()

# %% [markdown]
# - Fit the `benchmark_raw` model against the raw training data.
# - Score the `benchmark_raw` model against both the raw training set and the raw testing set.
# - Apprend a results dictionary to the `results` list.
#
# You could do this by
#
#     results.append({'name':'benchmark',
#                     'model': benchmark_raw,
#                     'dataset' : 'train',
#                     'preprocessing': 'raw',
#                     'score': raw_train_score})
#
# Of course you can store a model in a dictionary!

# %%
Xs_train.shape
# Out:
# (1087, 228)

# %%
benchmark_raw.fit(X_train, y_train)
raw_train_score = benchmark_raw.score(X_train, y_train)
raw_test_score = benchmark_raw.score(X_test, y_test)

results.append({'name':'benchmark',
                'model':benchmark_raw,
                'dataset' : 'train',
                'preprocessing': 'raw',
                'score': raw_train_score})
results.append({'name':'benchmark',
                'model':benchmark_raw,
                'dataset' : 'test',
                'preprocessing': 'raw',
                'score': raw_test_score})

# %% [markdown]
# #### Scaled Benchmark

# %% [markdown]
# - Fit the `benchmark_scaled` model against the scaled training data.
# - Score the `benchmark_scaled` model against both the scaled training set and the scaled testing set.
# - Write the results to the results `list`.

# %%
benchmark_scaled = LinearRegression()

# %%
benchmark_scaled.fit(Xs_train, y_train)
scaled_train_score = benchmark_scaled.score(Xs_train, y_train)
scaled_test_score = benchmark_scaled.score(Xs_test, y_test)

results.append({'name':'benchmark_scaled',
                'model':benchmark_scaled,
                'dataset' : 'train',
                'preprocessing': 'scaled',
                'score': scaled_train_score})
results.append({'name':'benchmark_scaled',
                'model':benchmark_scaled,
                'dataset' : 'test',
                'preprocessing': 'scaled',
                'score': scaled_test_score})

# %% [markdown]
# Use a DataFrame to display your results.

# %%
pd.DataFrame(results)
# Out:
#   dataset                                              model  \
# 0   train  LinearRegression(copy_X=True, fit_intercept=Tr...
# 1    test  LinearRegression(copy_X=True, fit_intercept=Tr...
# 2   train  LinearRegression(copy_X=True, fit_intercept=Tr...
# 3    test  LinearRegression(copy_X=True, fit_intercept=Tr...
#
#                name preprocessing         score
# 0         benchmark           raw  9.203445e-01
# 1         benchmark           raw  8.786256e-01
# 2  benchmark_scaled        scaled  9.202961e-01
# 3  benchmark_scaled        scaled -2.781444e+23

# %% [markdown]
# #### What are your observations? Add them to this markdown cell.
#
# ---

# %% [markdown]
# ### B. Naive Regularization
#
# Next, prepare a series of fits using the three regularized linear regression models with their default settings.
#
# Perform each of these against both the raw and the scaled data. In this section, you should be fitting six models.
#
# - A naive Ridge Regression against the raw data
# - A naive Lasso Regression against the raw data
# - A naive ElasticNet Regression against the raw data
# - A naive Ridge Regression against the scaled data
# - A naive Lasso Regression against the scaled data
# - A naive ElasticNet Regression against the scaled data
#
# **NOTE:** By "naive" we mean using all of the default settings.

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
Ridge_raw = Ridge()
Ridge_scaled = Ridge()
Lasso_raw = Lasso()
Lasso_scaled = Lasso()
El_raw = ElasticNet()
El_scaled = ElasticNet()

# %% [markdown]
# Note that we see warnings here. As we are in an exploration phase with our model, this is acceptable.

# %% [markdown]
# Use a DataFrame to store your `results` as `results_df`. By this we mean, save the `results` list into a new dataframe so that you can manipulate the DataFrame.

# %%
results_r = list()
Ridge_raw.fit(X_train, y_train)
Ridge_scaled.fit(Xs_train, y_train)


Rraw_train_score = Ridge_raw.score(Xs_train, y_train)
Rraw_test_score = Ridge_raw.score(Xs_test, y_test)
Rscaled_train_score = Ridge_scaled.score(Xs_train, y_train)
Rscaled_test_score = Ridge_scaled.score(Xs_test, y_test)


results.append({'name':'Ridge_Bench',
                'model':Ridge_raw,
                'dataset' : 'train',
                'preprocessing': 'raw',
                'score': Rraw_train_score})
results.append({'name':'Ridge_Bench',
                'model':Ridge_raw,
                'dataset' : 'test',
                'preprocessing': 'raw',
                'score': Rraw_test_score})
results.append({'name':'Ridge_Bench',
                'model':Ridge_scaled,
                'dataset' : 'train',
                'preprocessing': 'scaled',
                'score': Rscaled_train_score})
results.append({'name':'Ridge_Bench',
                'model':Ridge_scaled,
                'dataset' : 'test',
                'preprocessing': 'scaled',
                'score': Rscaled_test_score})

Lasso_raw.fit(X_train, y_train)
Lasso_scaled.fit(Xs_train, y_train)

Lraw_train_score = Lasso_raw.score(Xs_train, y_train)
Lraw_test_score = Lasso_raw.score(Xs_test, y_test)
Lscaled_train_score = Lasso_scaled.score(Xs_train, y_train)
Lscaled_test_score = Lasso_scaled.score(Xs_test, y_test)


results.append({'name':'Lasso_Bench',
                'model':Lasso_raw,
                'dataset' : 'train',
                'preprocessing': 'raw',
                'score': Lraw_train_score})
results.append({'name':'Lasso_Bench',
                'model':Lasso_raw,
                'dataset' : 'test',
                'preprocessing': 'raw',
                'score': Lraw_test_score})
results.append({'name':'Lasso_Bench',
                'model':Lasso_scaled,
                'dataset' : 'train',
                'preprocessing': 'scaled',
                'score': Lscaled_train_score})
results.append({'name':'Lasso_Bench',
                'model':Lasso_scaled,
                'dataset' : 'test',
                'preprocessing': 'scaled',
                'score': Lscaled_test_score})

El_raw.fit(X_train, y_train)
El_scaled.fit(Xs_train, y_train)

Eraw_train_score = El_raw.score(Xs_train, y_train)
Eraw_test_score = El_raw.score(Xs_test, y_test)
Escaled_train_score = El_scaled.score(Xs_train, y_train)
Escaled_test_score = El_scaled.score(Xs_test, y_test)


results.append({'name':'El_Bench',
                'model':El_raw,
                'dataset' : 'train',
                'preprocessing': 'raw',
                'score': Eraw_train_score})
results.append({'name':'El_Bench',
                'model':El_raw,
                'dataset' : 'test',
                'preprocessing': 'raw',
                'score': Eraw_test_score})
results.append({'name':'El_Bench',
                'model':El_scaled,
                'dataset' : 'train',
                'preprocessing': 'scaled',
                'score': Escaled_train_score})
results.append({'name':'El_Bench',
                'model':El_scaled,
                'dataset' : 'test',
                'preprocessing': 'scaled',
                'score': Escaled_test_score})
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
results
# Out:
# [{'dataset': 'train',
#   'model': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#   'name': 'benchmark',
#   'preprocessing': 'raw',
#   'score': 0.92034447290213728},
#  {'dataset': 'test',
#   'model': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#   'name': 'benchmark',
#   'preprocessing': 'raw',
#   'score': 0.87862563258319637},
#  {'dataset': 'train',
#   'model': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#   'name': 'benchmark_scaled',
#   'preprocessing': 'scaled',
#   'score': 0.92029613796947674},
#  {'dataset': 'test',
#   'model': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#   'name': 'benchmark_scaled',
#   'preprocessing': 'scaled',
#   'score': -2.7814443324363618e+23},
#  {'dataset': 'train',
#   'model': Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#      normalize=False, random_state=None, solver='auto', tol=0.001),
#   'name': 'Ridge_Bench',
#   'preprocessing': 'raw',
#   'score': -6.0268664936058043},
#  {'dataset': 'test',
#   'model': Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#      normalize=False, random_state=None, solver='auto', tol=0.001),
#   'name': 'Ridge_Bench',
#   'preprocessing': 'raw',
#   'score': -2.5188793464992063},
#  {'dataset': 'train',
#   'model': Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#      normalize=False, random_state=None, solver='auto', tol=0.001),
#   'name': 'Ridge_Bench',
#   'preprocessing': 'scaled',
#   'score': 0.92034211429863066},
#  {'dataset': 'test',
#   'model': Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#      normalize=False, random_state=None, solver='auto', tol=0.001),
#   'name': 'Ridge_Bench',
#   'preprocessing': 'scaled',
#   'score': 0.88623437813330841},
#  {'dataset': 'train',
#   'model': Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#      normalize=False, positive=False, precompute=False, random_state=None,
#      selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'Lasso_Bench',
#   'preprocessing': 'raw',
#   'score': -137.33550932509442},
#  {'dataset': 'test',
#   'model': Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#      normalize=False, positive=False, precompute=False, random_state=None,
#      selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'Lasso_Bench',
#   'preprocessing': 'raw',
#   'score': -109.04979278592623},
#  {'dataset': 'train',
#   'model': Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#      normalize=False, positive=False, precompute=False, random_state=None,
#      selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'Lasso_Bench',
#   'preprocessing': 'scaled',
#   'score': 0.92034431557255247},
#  {'dataset': 'test',
#   'model': Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#      normalize=False, positive=False, precompute=False, random_state=None,
#      selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'Lasso_Bench',
#   'preprocessing': 'scaled',
#   'score': 0.8865816560956169},
#  {'dataset': 'train',
#   'model': ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#         max_iter=1000, normalize=False, positive=False, precompute=False,
#         random_state=None, selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'El_Bench',
#   'preprocessing': 'raw',
#   'score': -52.362651063893523},
#  {'dataset': 'test',
#   'model': ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#         max_iter=1000, normalize=False, positive=False, precompute=False,
#         random_state=None, selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'El_Bench',
#   'preprocessing': 'raw',
#   'score': -56.539754764387474},
#  {'dataset': 'train',
#   'model': ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#         max_iter=1000, normalize=False, positive=False, precompute=False,
#         random_state=None, selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'El_Bench',
#   'preprocessing': 'scaled',
#   'score': 0.90190479731092421},
#  {'dataset': 'test',
#   'model': ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#         max_iter=1000, normalize=False, positive=False, precompute=False,
#         random_state=None, selection='cyclic', tol=0.0001, warm_start=False),
#   'name': 'El_Bench',
#   'preprocessing': 'scaled',
#   'score': 0.88767655599468642}]

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#    dataset                                              model  \
# 0    train  LinearRegression(copy_X=True, fit_intercept=Tr...
# 1     test  LinearRegression(copy_X=True, fit_intercept=Tr...
# 2    train  LinearRegression(copy_X=True, fit_intercept=Tr...
# 3     test  LinearRegression(copy_X=True, fit_intercept=Tr...
# 4    train  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 5     test  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 6    train  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 7     test  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 8    train  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 9     test  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 10   train  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 11    test  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 12   train  ElasticNet(alpha=1.0, copy_X=True, fit_interce...
# 13    test  ElasticNet(alpha=1.0, copy_X=True, fit_interce...
# 14   train  ElasticNet(alpha=1.0, copy_X=True, fit_interce...
# 15    test  ElasticNet(alpha=1.0, copy_X=True, fit_interce...
#
#                 name preprocessing         score
# 0          benchmark           raw  9.203445e-01
# 1          benchmark           raw  8.786256e-01
# 2   benchmark_scaled        scaled  9.202961e-01
# 3   benchmark_scaled        scaled -2.781444e+23
# 4        Ridge_Bench           raw -6.026866e+00
# 5        Ridge_Bench           raw -2.518879e+00
# 6        Ridge_Bench        scaled  9.203421e-01
# 7        Ridge_Bench        scaled  8.862344e-01
# 8        Lasso_Bench           raw -1.373355e+02
# 9        Lasso_Bench           raw -1.090498e+02
# 10       Lasso_Bench        scaled  9.203443e-01
# 11       Lasso_Bench        scaled  8.865817e-01
# 12          El_Bench           raw -5.236265e+01
# 13          El_Bench           raw -5.653975e+01
# 14          El_Bench        scaled  9.019048e-01
# 15          El_Bench        scaled  8.876766e-01

# %% [markdown]
# #### Display just the raw test results using pandas

# %% [markdown]
# You can do this using pandas indexing as follows
#
#     results_df[(results_df.preprocessing == 'raw') &
#                (results_df.dataset == 'test')]

# %%
results_df[(results_df.preprocessing == 'raw') & 
           (results_df.dataset == 'test')]
# Out:
#    dataset                                              model         name  \
# 1     test  LinearRegression(copy_X=True, fit_intercept=Tr...    benchmark
# 5     test  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...  Ridge_Bench
# 9     test  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...  Lasso_Bench
# 13    test  ElasticNet(alpha=1.0, copy_X=True, fit_interce...     El_Bench
#
#    preprocessing       score
# 1            raw    0.878626
# 5            raw   -2.518879
# 9            raw -109.049793
# 13           raw  -56.539755

# %% [markdown]
# #### What are your observations? Add them to this markdown cell.
#
# ---

# %% [markdown]
# #### Display just the scaled test results

# %%
results_df[(results_df.preprocessing == 'scaled') & 
           (results_df.dataset == 'test')]
# Out:
#    dataset                                              model  \
# 3     test  LinearRegression(copy_X=True, fit_intercept=Tr...
# 7     test  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 11    test  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...
# 15    test  ElasticNet(alpha=1.0, copy_X=True, fit_interce...
#
#                 name preprocessing         score
# 3   benchmark_scaled        scaled -2.781444e+23
# 7        Ridge_Bench        scaled  8.862344e-01
# 11       Lasso_Bench        scaled  8.865817e-01
# 15          El_Bench        scaled  8.876766e-01

# %% [markdown]
# #### What are your observations? Add them to this markdown cell.
#
# ---

# %% [markdown]
# These are your benchmark results. You will refer to these for analysis during the next phase.

# %% [markdown]
# #### Display just the Benchmark models

# %%
results_df[(results_df.preprocessing == 'raw') & 
           (results_df.dataset == 'test')]
# Out:
#    dataset                                              model         name  \
# 1     test  LinearRegression(copy_X=True, fit_intercept=Tr...    benchmark
# 5     test  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...  Ridge_Bench
# 9     test  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...  Lasso_Bench
# 13    test  ElasticNet(alpha=1.0, copy_X=True, fit_interce...     El_Bench
#
#    preprocessing       score
# 1            raw    0.878626
# 5            raw   -2.518879
# 9            raw -109.049793
# 13           raw  -56.539755

# %% [markdown]
# #### Display just the Ridge models

# %%
results_df[(results_df.name == 'Ridge_Bench')]
# Out:
#   dataset                                              model         name  \
# 4   train  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...  Ridge_Bench
# 5    test  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...  Ridge_Bench
# 6   train  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...  Ridge_Bench
# 7    test  Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...  Ridge_Bench
#
#   preprocessing     score
# 4           raw -6.026866
# 5           raw -2.518879
# 6        scaled  0.920342
# 7        scaled  0.886234

# %% [markdown]
# #### Display just the Lasso models

# %%
results_df[(results_df.name == 'Lasso_Bench')]
# Out:
#    dataset                                              model         name  \
# 8    train  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...  Lasso_Bench
# 9     test  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...  Lasso_Bench
# 10   train  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...  Lasso_Bench
# 11    test  Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...  Lasso_Bench
#
#    preprocessing       score
# 8            raw -137.335509
# 9            raw -109.049793
# 10        scaled    0.920344
# 11        scaled    0.886582

# %% [markdown]
# #### Display just the Elasticnet models

# %%
results_df[(results_df.name == 'El_Bench')]
# Out:
#    dataset                                              model      name  \
# 12   train  ElasticNet(alpha=1.0, copy_X=True, fit_interce...  El_Bench
# 13    test  ElasticNet(alpha=1.0, copy_X=True, fit_interce...  El_Bench
# 14   train  ElasticNet(alpha=1.0, copy_X=True, fit_interce...  El_Bench
# 15    test  ElasticNet(alpha=1.0, copy_X=True, fit_interce...  El_Bench
#
#    preprocessing      score
# 12           raw -52.362651
# 13           raw -56.539755
# 14        scaled   0.901905
# 15        scaled   0.887677

# %% [markdown]
# #### What are your observations? Add them to this markdown cell.
#
# ---

# %% [markdown]
# ### C. Cross-validated models
#
# Import the Cross-Validation Models for each of the Regularized Linear Models

# %%
cv_results = list()

# %%
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV

# %% [markdown]
# Perform the cross-validation using an `np.logspace(-2,4,7)`.

# %%
ridge_alphas = np.logspace(-2, 4, 7)

optimal_ridge_scale = RidgeCV(alphas=ridge_alphas, cv=3)
optimal_ridge_scale.fit(Xs_train, y_train)
optimal_ridge_score_scaled = optimal_ridge_scale.score(Xs_train, y_train)
optimal_ridge_raw = RidgeCV(alphas=ridge_alphas, cv=3)
optimal_ridge_raw.fit(X_train, y_train)
optimal_ridge_score_raw = optimal_ridge_raw.score(X_train, y_train)


cv_results.append({'name':'El_Bench',
                'model':optimal_ridge_raw,
                'dataset' : 'train',
                'preprocessing': 'raw',
                'score':optimal_ridge_score_raw})
cv_results.append({'name':'El_Bench',
                'model':optimal_ridge_scale,
                'dataset' : 'test',
                'preprocessing': 'scaled',
                'score': optimal_ridge_score_scaled})



print(optimal_ridge_raw.alpha_)
print(optimal_ridge_scale.alpha_)
# Out:
# 10.0
# 1000.0

# %%
lasso_alphas = np.logspace(-2, 4, 7)

optimal_lasso_scale = LassoCV(alphas=lasso_alphas, cv=3)
optimal_lasso_scale.fit(Xs_train, y_train)
optimal_lasso_score_scaled = optimal_lasso_scale.score(Xs_train, y_train)
optimal_lasso_raw = LassoCV(alphas=lasso_alphas, cv=3)
optimal_lasso_raw.fit(X_train, y_train)
optimal_lasso_score_raw = optimal_lasso_raw.score(X_train, y_train)


cv_results.append({'name':'El_Bench',
                'model':optimal_lasso_raw,
                'dataset' : 'train',
                'preprocessing': 'raw',
                'score':optimal_lasso_score_raw})
cv_results.append({'name':'El_Bench',
                'model':optimal_lasso_scale,
                'dataset' : 'test',
                'preprocessing': 'scaled',
                'score': optimal_lasso_score_scaled})



print(optimal_lasso_raw.alpha_)
print(optimal_lasso_scale.alpha_)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 100.0
# 1000.0

# %%
ElasticNet_alphas = np.logspace(-2, 4, 7)

optimal_ElasticNet_scale = ElasticNetCV(alphas=ElasticNet_alphas, cv=3)
optimal_ElasticNet_scale.fit(Xs_train, y_train)
optimal_ElasticNet_score_scaled = optimal_ElasticNet_scale.score(Xs_train, y_train)
optimal_ElasticNet_raw = ElasticNetCV(alphas=ElasticNet_alphas, cv=3)
optimal_ElasticNet_raw.fit(X_train, y_train)
optimal_ElasticNet_score_raw = optimal_ElasticNet_raw.score(X_train, y_train)


cv_results.append({'name':'El_Bench',
                'model':optimal_ElasticNet_raw,
                'dataset' : 'train',
                'preprocessing': 'raw',
                'score':optimal_ElasticNet_score_raw})
cv_results.append({'name':'El_Bench',
                'model':optimal_ElasticNet_scale,
                'dataset' : 'test',
                'preprocessing': 'scaled',
                'score': optimal_ElasticNet_score_scaled})



print(optimal_ElasticNet_raw.alpha_)
print(optimal_ElasticNet_scale.alpha_)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0.01
# 1.0
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# #### Display just the raw test results

# %%
cv_df = pd.DataFrame(cv_results)
cv_df.head()
cv_df[(cv_df.preprocessing == 'raw')]
# Out:
#   dataset                                              model      name  \
# 0   train  RidgeCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 2   train  LassoCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 4   train  ElasticNetCV(alphas=array([  1.00000e-02,   1....  El_Bench
#
#   preprocessing     score
# 0           raw  0.897507
# 2           raw  0.905377
# 4           raw  0.902286

# %% [markdown]
# #### Display just the scaled test results

# %%
cv_df[(cv_df.preprocessing == 'scaled')]
# Out:
#   dataset                                              model      name  \
# 1    test  RidgeCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 3    test  LassoCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 5    test  ElasticNetCV(alphas=array([  1.00000e-02,   1....  El_Bench
#
#   preprocessing     score
# 1        scaled  0.885973
# 3        scaled  0.905116
# 5        scaled  0.901905

# %% [markdown]
# ### D. Model Selection
#
# Interpret Regression Metrics for each of your models. Choose one of the following:
#
# * R2
# * MSE / RMSE
# * MAE
#
# What are your top 3 performing models?

# %%
models = [optimal_ridge_raw,optimal_ridge_scale, optimal_lasso_raw,optimal_lasso_scale, optimal_ElasticNet_raw,\
          optimal_ElasticNet_scale]
cv_df.head()
# Out:
#   dataset                                              model      name  \
# 0   train  RidgeCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 1    test  RidgeCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 2   train  LassoCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 3    test  LassoCV(alphas=array([  1.00000e-02,   1.00000...  El_Bench
# 4   train  ElasticNetCV(alphas=array([  1.00000e-02,   1....  El_Bench
#
#   preprocessing     score
# 0           raw  0.897507
# 1        scaled  0.885973
# 2           raw  0.905377
# 3        scaled  0.905116
# 4           raw  0.902286

# %%
import sklearn.metrics 
for i in models:
    print(sklearn.metrics.r2_score(cv_df.score.values, y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-ac2e2601951a> in <module>()
#       1 import sklearn.metrics
#       2 for i in models:
# ----> 3     print(sklearn.metrics.r2_score(cv_df.score.values, y))
#
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     453     """
#     454     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 455         y_true, y_pred, multioutput)
#     456
#     457     if sample_weight is not None:
#
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      72
#      73     """
# ---> 74     check_consistent_length(y_true, y_pred)
#      75     y_true = check_array(y_true, ensure_2d=False)
#      76     y_pred = check_array(y_pred, ensure_2d=False)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [6, 1450]

# %% [markdown]
# ## Explain the bias / variance tradeoff
#
# Why do regularized models perform better on your test set?

# %% [markdown]
# They have found the most harmonious balance of bias and variance

# %% [markdown]
# ### Interpreting coefficients
#
# For your best model,
#
# * plot relevant coefficients using the `plot_coef` functoin.

# %%
def plot_coef(model, top_n = 10):
    '''
    Plots the magnitude of top and bottom n coefficients
    '''
    cols = X_train.columns
    coef = model.coef_
    zipped = list(zip(cols, coef))
    zipped.sort(key=lambda x: x[1], reverse = True)
    top_10 = pd.DataFrame(zipped).head(top_n)
    bottom_10 = pd.DataFrame(zipped).tail(top_n)
    return pd.concat([top_10, bottom_10], axis=0).plot.barh(x = 0, y = 1)

# %% [markdown]
# #### Plot your coefficients.

# %%
for i in models:
    plot_coef(i)

# %% [markdown]
# #### Which features add / take away most value from a home?

# %% [markdown]
# # (Optional) Informing Business Value
#
# Interpreting our work for a non-technical audience is a vital skill that every good Data Scientist must cultivate.  At the end of the day, our work must be informative to business process so connecting our detailed efforts to a high level strategy is critical.
#
# We've established a few businesses cases that you should assert some explanation and advise best strategy through a model of your choice.  Also call out any exploratory analysis and reasoning for any recommendation.
#
# ##### For each question:
# * Plot relevant data
# * Fit a new model or use a previous  model
# * Plot relevant coefficients

# %% [markdown]
# #### (Optional) Case 1: Which features add / take away most value from a home?
#
# You just explained which coeffients add / take away most value, technically, but can you explain this in a non-technical manner?  Also, emphasize _why_ in your explanation.
#
# - Choose a few examples and explain why the coefficients describe the target value of the property.

# %% [markdown]
# #### (Optional) Case 2: Can you identify any abnormally priced houses?
# We might consider these being properties that are over or under predicted by price. Can you make sense of when and why these are over and under predicted?

# %% [markdown]
# #### (Optional) Case 3:  Which houses are good investments?
#
# Which criteria would you look at?  How sure can you be of your assumptions?  Give precise metrics but also give a concise recommendation that is non-technical that communicates the risks of your anlaysis.

# %% [markdown]
# #### (Optional) Case 4:  Which houses are good investments (extended)?
# One idea that is common in the real-estate invement community is called "flipping".  This usually entails buying a property with "changable" charactaristics that can be upgraded.  Examples of changable or "upgradable" features include:  A garage, a kitchen, etc.
#
# Can you give us an idea of investments opportunities considering "upgradable" features?  You will have to explore this idea on your own and possibly do a little research for subject matter expertise.
#
# - Some features of a house are worth more than others
# - Some features can't be upgraded (ie: square footage)
